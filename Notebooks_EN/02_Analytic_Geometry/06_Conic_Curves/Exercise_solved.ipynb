# %% [markdown]
# <a href="https://colab.research.google.com/github/Zalina1276/Math-2024-25-Winter/blob/main/Notebooks_EN/02_Analytic_Geometry/06_Conic_Curves/Exercise_solved.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notes**
# ## **Circle**
# The equation of a circle with center $(h,k)$ and radius $(r)$ is:
#
# $$(x-h)^2+(y-k)^2=r^3$$
#
# ## **Parabola**
# To find the equation of the parabola, we start with its general quadratic form:
#
# $$y=ax^2+bx+c$$
#
# The equation of a parabola opening vertically with vertex $(h,k)$ and parameter $(p)$ (distance from the vertex to the focus) is:
#
# $$ (y-k)=\frac{1}{4p} (x-h)^2$$
#
# ## **Ellipse**
# The general form of an ellipse centered at $(h,k)$ with semi-major axis $a$ and semi-minor axis $b$ is:
#
# $$\frac{(x-h)^2}{a}+ \frac{(y-k)^2}{b}=1$$
#
# ## **Hyperbola**
# The standard form of a hyperbola centered at $(h,k)$, with transverse axis length $2a$ and conjugate axis length $2b$, is:
#
# $$\frac{(x-h)^2}{a^2} - \frac{(y-k)^2}{b^2}$$

# %% [markdown]
#  # **Exercises**
#
#  1)Find the equation of a circle with center at point $A(1,2)$ and radius $r=3$
#
#  2)Find the equation of a parabola intersecting the $Ox$ axis at points $x=2$, $x=4$, and passing through point $y(3)=1$.
#
#  3)Find the center of the ellipse with the equation $x^2 + 4y^2 - 4x - 16y + 16 = 0$.
#
#  4)Find the slope ($m>0$) of the line $y=mx-5$ that is tangent to the circle with the equation $x^2 + y^2=1$.
#
#  5)Find the intersection points of the hyperbola $x^2 - y^2 = 1$ with the ellipse's line $x^2 + 4y^2 = 6$.
#
#  6)For the given hyperbola $x^2 - y^2 = 1$, find the distance between its branches.

# %% [markdown]
# # **Homework**
# ## **Exercise 1**
#
# $A(1,2)$ and $r=3$
#
# The solution is:
#
# $(x-1)^2+(y-2)^2=3^2$
#
# $\boxed{(x-1)^2+(y-2)^2=9}$
#
#
# ## **Exercise 2**
#
# $x=2$, $x=4$, $y(3)=1$
#
# 1)$y=(x-2)(x-4)$
#
# 2)$1=a(3-2)(3-4)$
#
# $1=-1a$
#
# $a=-1$
#
# 3)$y=-1(x-2)(x-4)$
#
# $y=-1(x^2-2x-4x+8)$
#
# $\boxed{y=-x^2+6x-8}$
#
# ##**Exercise 3**
# $x^2 + 4y^2 - 4x - 16y + 16 = 0$
#
# $(x^2-4x)+4(y^2-4y)=-16$
#
# 1)$x^2-4x=(x-2)^2 - 4$
#
# 2)$y^2-4y=(y-2)^2-4$
#
# 3)$(x-2)^2-4+4((y-2)-4)$
#
# $(x-2)^2+4(y-2)^2-16=-16$
#
# $(x-2)^2+4(y-2)^2-20=-16$
#
# $(x-2)^2+4(y-2)^2=4$
#
# 4)$\frac{(x-2)^2}{4} + \frac{(y-2)^2}{1}=1$
#
# The center of the eclipse is $\boxed{(2,2)}$
#
# ## **Exercise 4**
# Slope $( m > 0 )$ of the line $ y = mx - 5 $ that is tangent to the circle $x^2 + y^2 = 1$
#
# 1)$x^2 + y^2 = 1$
#
# $x^2 + (mx - 5)^2 = 1$
#
# $x^2 + (m^2x^2 - 10mx + 25) = 1$
#
# $x^2 + m^2x^2 - 10mx + 25 = 1$
#
# $(1 + m^2)x^2 - 10mx + 24 = 0$
#
# 2)$\Delta = (-10m)^2 - 4(1 + m^2)(24)$
#
# $\Delta = 100m^2 - 96(1 + m^2)$
#
# $\Delta = 100m^2 - 96 - 96m^2$
#
# $\Delta = 4m^2 - 96$
#
# For the line to be tangent to the circle, the quadratic equation must have exactly one solution, meaning the discriminant is zero
#
# 3)$4m^2 - 96 = 0$
#
# $4m^2 = 96$
#
# $m^2 = 24$
#
# $m = \sqrt{24} = \boxed{2\sqrt{6}} \quad (\text{since } m > 0)$
#
# ## **Exercise 5**
# Hyperbola $x^2 - y^2 = 1$ , ellipse $x^2 + 4y^2 = 6$
#
# 1)$x^2 = y^2 + 1$
#
# 2)$ (y^2 + 1) + 4y^2 = 6 $
#
# $y^2 + 1 + 4y^2 = 6$
#
# $5y^2 + 1 = 6$
#
# $5y^2 = 5$
#
# $y^2 = 1$
#
# $y = \pm 1$
#
# 3)For $y = 1$:
#
# $x^2 = 1^2 + 1 = 2$
#
# $x = \pm \sqrt{2}$.
#
# 4)For $y = -1$:
#
# $x^2 = (-1)^2 + 1 = 2$
#
# $x = \pm \sqrt{2}$.
#
# The intersection points of the hyperbola and the ellipse are
#
# $\boxed{(\sqrt{2}, 1), (-\sqrt{2}, 1), (\sqrt{2}, -1), (-\sqrt{2}, -1)}$
#
# ## **Exercise 6**
# Hyperbola $x^2 - y^2 = 1$
#
# The given equation is already in the standard form for a hyperbola centered at the origin:
#
# $\frac{x^2}{a^2} - \frac{y^2}{b^2} = 1$
#
# $a^2 = 1 \quad \Rightarrow a = 1$
#
# $b^2 = 1 \quad \Rightarrow b = 1$
#
# For a hyperbola of the form $\frac{x^2}{a^2} - \frac{y^2}{b^2} = 1$, the branches of the hyperbola are located at points where $y = 0$. At these points, the equation simplifies to:
#
# $\frac{x^2}{a^2} = 1 \quad \Rightarrow x = \pm a$
#
# $x = \pm 1$.
#
# The distance between the branches is the horizontal distance between the points $x = 1$ and $x = -1$. This distance is:
#
# $\mathbf{Distance} = |1 - (-1)| =\boxed{2}$
