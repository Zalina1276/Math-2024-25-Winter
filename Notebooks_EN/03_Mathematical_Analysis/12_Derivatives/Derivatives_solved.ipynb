# %% [markdown]
# <a href="https://colab.research.google.com/github/Zalina1276/Math-2024-25-Winter/blob/main/Notebooks_EN/03_Mathematical_Analysis/12_Derivatives/Derivatives_solved.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **21. Derivatives**
#
# 1. Compute derivatives of functions:
#    * $y(x) = -3x+3$
#    * $y(x) = \pi x + \sin(1)$
#    * $y(x) = 4+\sin(2)$
#    * $y(x) = 2x^3 - 3x^2 + 8x - 9$
#    * $y(x) = 6 x^{1/3}$
#    * $y(x) = \sqrt{x}$
#    * $y(x) = \cos(x) + \sin(x)$
#    * $y(x) = 2\sin(x) \cos(x)$
#    * $y(x) = x\sin(x)$
#    * $y(x) = (x+1)(x+1)$
#    * $y(x) = \frac{x}{x+1}$
#    * $y(x) = (x+1)\exp(x)$
#    * $y(x) = \sin(x^2)$
#    * $y(x) = \exp(-2x)$
#    * $y(x) = \frac{1}{\sin(x+1)}$
#    * $y(x) = \sqrt{2x+1}$
#
# 2. Prove:
#    - $\frac{d}{dx} (\ln(\sin(x))) = \cot(x)$
#
# 3. For $f(x) = \cos(x)$, verify that $f''(x) = -f(x)$.
#
# 4. Using de l'Hospital's Rule, find the improper limits:
#    - $\displaystyle \lim_{x\to 0} \frac{\sin{x}}{x}$
#
#    - $\displaystyle \lim_{x\to \infty} \frac{\ln x}{x}$
#
#    - $\displaystyle \lim_{x\to \infty} \frac{ e^x}{x}$
#
# 5. In physics, the position of a particle is given by $x(t) = 3t^2 - 6t + 1$. Find the velocity $V(t)=x'(t)$ and acceleration $a(t)=V'(t)=x''(t)$ of the particle at time $t = 2$.

# %% [markdown]
# # ***Homework***
# ## **Exercise 1**
# ### 1. $ y(x) = -3x + 3 $
#
# $(-3x+3)'=(-3x)'+(3)'=(-3x)'+0=(-3)'x+(-3)x'=0-3*1=-3 $
#
# The function is a linear function, so the derivative of any linear term $ ax + b $ is simply the coefficient $ a $.
#
# $y'(x) = -3$
#
# Explanation: The derivative of $ -3x $ is $ -3 $ and the derivative of a constant $ 3 $ is $ 0 $.
#
# ---
# ### 2. $ y(x) = \pi x + \sin(1) $
#
# $y'(x)= (πx+ \sin(1))'= (\pi x)'+ (\sin(1))'=(\pi)'(x)+ (\pi)x'=0+ \pi= \pi $
#
# Here, $ \pi $ is a constant, and $ \sin(1) $ is also a constant.
#
# $y'(x) = \pi$
#
# Explanation: The derivative of $ \pi x $ is $ \pi $, and the derivative of any constant (like $ \sin(1) $) is $ 0 $.
#
# ---
#
# ### 3. $ y(x) = 4 + \sin(2) $
#
# $4+ \sin(2)=c$
#
# $c'=0$
#
# $y'(x) = 0$
#
# Explanation: The derivative of any constant is $ 0 $.
#
# ---
#
# ### 4. $ y(x) = 2x^3 - 3x^2 + 8x - 9 $
# We differentiate each term using the **power rule**, which says that the derivative of $$x^n= n \cdot x^{n-1} $$
#
# $y'(x) = 6x^2 - 6x + 8$
#
# ---
#
# ### 5. $ y(x) = 6x^{1/3} $
# We apply the power rule for $ x^n $, where the derivative of $ x^n $ is $ n \cdot x^{n-1} $.
#
# $y'(x) = 6 \cdot \frac{1}{3} x^{-2/3} = 2x^{-2/3}$
#
# Explanation: The derivative of $ x^{1/3} $ is $ \frac{1}{3} x^{-2/3} $, and multiplying by 6 gives $ 2x^{-2/3} $.
#
# ---
#
# ### 6. $ y(x) = \sqrt{x} $
# We can rewrite $ \sqrt{x} $ as $ x^{1/2} $.
#
# $y'(x) = \frac{1}{2} x^{-1/2} = \frac{1}{2\sqrt{x}}$
#
# Explanation: Using the power rule, the derivative of $ x^{1/2} $ is $ \frac{1}{2} x^{-1/2} $, which is equivalent to $ \frac{1}{2\sqrt{x}} $.
#
# ---
#
# ### 7. $ y(x) = \cos(x) + \sin(x) $
# We differentiate each trigonometric term.
#
# $y'(x) = -\sin(x) + \cos(x)$
#
# Explanation: The derivative of $ \cos(x) $ is $ -\sin(x) $, and the derivative of $ \sin(x) $ is $ \cos(x) $.
#
# ---
#
# ### 8. $ y(x) = 2\sin(x)\cos(x) $
# This is a product of two functions, so we use the **product rule**. The product rule states that the derivative of $$ u(x)v(x)  =  u'(x)v(x) + u(x)v'(x) $$.
#
# $y'(x) = 2\left( \cos(x) \cdot \cos(x) - \sin(x) \cdot \sin(x) \right) = 2\cos(2x)$
#
# Explanation: Using the trigonometric identity $ 2\sin(x)\cos(x) = \sin(2x) $, we can simplify the derivative as $ 2\cos(2x) $.
#
# ---
#
# ### 9. $ y(x) = x \sin(x) $
# This is again a product of two functions, so we use the product rule.
#
# $y'(x) = \sin(x) + x \cos(x)$
#
# Explanation: The derivative of $ x $ is $ 1 $, so we get $ \sin(x) $, and the derivative of $ \sin(x) $ is $ \cos(x) $, so we get $ x \cos(x) $.
#
# ---
#
# ### 10. $ y(x) = (x+1)(x+1) = (x+1)^2 $
# We apply the power rule. The derivative of $ (x+1)^2 $ is $ 2(x+1) $.
#
# $y'(x) = 2(x+1)*1=2(x+1)$
#
# Explanation: The derivative of $ (x+1)^2 $ is $ 2(x+1) $ using the power rule.
#
# ---
# ### 11. $ y(x) = \frac{x}{x+1} $
# We use the **quotient rule**, which states that for $ \frac{u(x)}{v(x)} $, the derivative is:
#
# $$
# y'(x) = \frac{v(x)u'(x) - u(x)v'(x)}{(v(x))^2}
# $$
# $y'(x) = \frac{(x+1)(1) - x(1)}{(x+1)^2} = \frac{1}{(x+1)^2}$
#
# Explanation: The derivative of \( x \) is 1, and the derivative of \( x+1 \) is also 1. So the quotient rule gives us the result.
#
# ---
# ### 12. $ y(x) = (x+1) e^x $
# We use the product rule again.
#
# $y'(x) = e^x + (x+1) e^x = (x+2)e^x$
#
# Explanation: The derivative of $ e^x $ is $ e^x $, and the derivative of $x+1$ is $ 1 $, so we get the result.
#
# ---
# ### 13. $ y(x) = \sin(x^2) $
# We use the **chain rule**. The chain rule states that for a composition of functions $$ f(g(x))= f'(g(x)) \cdot g'(x) $$
#
# $y'(x) = 2x \cos(x^2)$
#
# Explanation: The derivative of $ \sin(u) $ is $ \cos(u) $, and the derivative of $ x^2 $ is $ 2x $. So we multiply $ 2x $ by $ \cos(x^2) $.
#
# ---
# ### 14. $ y(x) = e^{-2x} $
# We apply the chain rule.
#
# $y'(x) = -2e^{-2x}$
#
# Explanation: The derivative of $e^u $ is $ e^u \cdot u'$, where $ u = -2x $, so the derivative of $ -2x $ is $ -2 $, giving the result.
#
# ---
# ### 15. $ y(x) = \frac{1}{\sin(x+1)} $
# This is a quotient, so we apply the quotient rule.
#
# $y'(x) = -\frac{\cos(x+1)}{\sin^2(x+1)}$
#
# Explanation: The derivative of $ \sin(x+1) $ is $ \cos(x+1) $ by the chain rule, and we apply the quotient rule to find the result.
#
# ---
# ### 16. $ y(x) = \sqrt{2x+1} $
# We use the chain rule. Rewrite the square root as $(2x+1)^{1/2}$
#
# $y'(x) =\frac{1}{2}(2x+1)^{-1/2} = \frac{1}{2} \cdot 2(2x+1)^{-1/2}= \frac{1}{\sqrt{2x+1}}$
#
# Explanation: The derivative of $ (2x+1)^{1/2} $ is $ \frac{1}{2}(2x+1)^{-1/2}$, and then multiply by the derivative of $ 2x+1 $, which is 2.
#
# ## **Exercise 2**
# $\frac{d}{dx} \left(\ln(\sin(x))\right) = \cot(x)$
#
# We know that:
#
# $$
# \frac{d}{dx} \left(\ln(u(x))\right) = \frac{u'(x)}{u(x)}
# $$
#
# Let $ u(x) = \sin(x) $, so:
#
# $\frac{d}{dx} \left(\ln(\sin(x))\right) = \frac{\frac{d}{dx}(\sin(x))}{\sin(x)}$
#
# The derivative of $ \sin(x) $ is:
#
# $\frac{d}{dx}(\sin(x)) = \cos(x)$
#
# So we substitute this result back into the expression:
#
# $\frac{d}{dx} \left(\ln(\sin(x))\right) = \frac{\cos(x)}{\sin(x)}$
#
# From trigonometry, we know that:
#
# $$
# \cot(x) = \frac{\cos(x)}{\sin(x)}
# $$
#
# Thus:
#
# $\frac{d}{dx} \left(\ln(\sin(x))\right) = \cot(x)$
#
# ## **Exercise 3**
# $f(x)= \cos(x)$
#
# $f'(x)= -\sin(x)$
#
# $f''(x)= -\cos(x)$
#
# $f''(x)=-f(x)$
#
# ## **Exercise 4**
# - $\displaystyle \lim_{x \to 0} \frac{\sin(x)}{x} $
#
# ###  Check Indeterminate Form
# We substitute $ x = 0 $:
#
# $\frac{\sin(0)}{0} = \frac{0}{0}$
#
# This is an indeterminate form, so we can apply **de l'Hôpital's Rule**, which states:
#
# $$
# \displaystyle \lim_{x \to c} \frac{f(x)}{g(x)} = \lim_{x \to c} \frac{f'(x)}{g'(x)}
# $$
#
# $\displaystyle \lim_{x \to 0} \frac{\sin(x)}{x}= \frac{\cos(x)}{1} = \cos(0) = 1$
#
# ---
# - $\displaystyle \lim_{x \to \infty} \frac{\ln(x)}{x} $
#
# ### Check Indeterminate Form
# We substitute $ x \to \infty $:
#
# $\frac{\ln(x)}{x} \to \frac{\infty}{\infty}$
#
# This is an indeterminate form, so we apply de l'Hôpital's Rule.
#
# $f(x) = \ln(x), \quad f'(x) = \frac{1}{x}$
#
# $g(x) = x, \quad g'(x) = 1$
#
# Applying de l'Hôpital's Rule:
#
# $\displaystyle \lim_{x \to \infty} \frac{\frac{1}{x}}{1} = \displaystyle \lim_{x \to \infty} \frac{1}{x}$
#
# As $ x \to \infty $, $ \frac{1}{x} \to 0 $
#
# $\displaystyle \lim_{x \to \infty} \frac{\ln(x)}{x} = 0$
#
# ---
# - $\displaystyle \lim_{x \to \infty} \frac{e^x}{x} $
#
# ### Check Indeterminate Form
#
# $\frac{e^x}{x} \to \frac{\infty}{\infty}$
#
# This is an indeterminate form, so we apply de l'Hôpital's Rule.
#
# $f(x) = e^x, \quad f'(x) = e^x$
#
# $g(x) = x, \quad g'(x) = 1$
#
# Applying de l'Hôpital's Rule:
#
# $\displaystyle \lim_{x \to \infty} \frac{e^x}{1} = \displaystyle  \lim_{x \to \infty} e^x$
#
# Since $ e^x \to \infty $, the result is:
#
# $ \displaystyle \lim_{x \to \infty} \frac{e^x}{x} = \infty$
#
# ## **Exercise 5**
# $x(t) =3t^2 - 6t +1 $, $t=2$. Find: V(t), a(t)
#
# $V(t)= x'(t)= 6t - 6$
#
# $V(2)=6*2 - 6= 6$
#
# $a(t)=V'(t)= x''(t)= 6$
#
# $a(2)=6$
#
# Final answer: $V(t)= 6, a(t)= 6$
